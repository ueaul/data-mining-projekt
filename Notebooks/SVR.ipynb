# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler
from sklearn.utils import resample
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import cross_val_score
from scipy.sparse import csr_matrix

# %%
# Load your dataset
df = pd.read_csv('ds_salaries.csv')

# %%
# Preprocessing
# Split the dataset into training and test data
df_target = df['salary_in_usd']

# Remove target variable from the DataFrame
df_features = df.drop('salary_in_usd', axis=1)

# Initialize the OneHotEncoder from sklearn
encoder = OneHotEncoder(sparse=False)

# Fit and transform the features DataFrame
df_features_encoded = encoder.fit_transform(df_features)

# Convert the array back to a DataFrame
df_features_encoded = pd.DataFrame(df_features_encoded, columns=encoder.get_feature_names_out(df_features.columns))

# Add the target variable back to the DataFrame
df_preprocessed = pd.concat([df_features_encoded, df_target], axis=1)

# %%
# Split the dataset
df_train, df_test = train_test_split(df_preprocessed, test_size=0.3, random_state=42)

# %%
# Copy train dataset for a comparison without oversampling
df_train_without_oversampling = df_train.copy()

# %%
# Oversample using RESAMPLE
def oversample_data(df_input):
    # Separate majority and minority classes
    df_majority = df_input[df_input.company_size_M==1.0]
    df_minority_large = df_input[df_input.company_size_L==1.0]
    df_minority_small = df_input[df_input.company_size_S==1.0]

    # Upsample minority classes
    df_minority_large_upsampled = resample(df_minority_large, 
                                     replace=True,    # sample with replacement
                                     n_samples=len(df_majority),  # to match majority class
                                     random_state=123) # reproducible results

    df_minority_small_upsampled = resample(df_minority_small, 
                                     replace=True,    # sample with replacement
                                     n_samples=len(df_majority),  # to match majority class
                                     random_state=123) # reproducible results

    # Combine majority class with upsampled minority classes
    df_upsampled = pd.concat([df_majority, df_minority_large_upsampled, df_minority_small_upsampled])
    
    return df_upsampled

df_train = oversample_data(df_train)

# %%
# Prepare the data for model training
X_train = df_train.drop(['salary_in_usd'], axis=1)
y_train = df_train['salary_in_usd']
X_test = df_test.drop(['salary_in_usd'], axis=1)
y_test = df_test['salary_in_usd']

X_train_without_oversampling = df_train_without_oversampling.drop(['salary_in_usd'], axis=1)
y_train_without_oversampling = df_train_without_oversampling['salary_in_usd']

X_train = csr_matrix(X_train.values)
X_test = csr_matrix(X_test.values)
X_train_without_oversampling = csr_matrix(X_train_without_oversampling.values)

# %%
# Define the model
svr = SVR()
svr_without_oversampling = SVR()

# Define the hyperparameters
param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001], 'kernel': ['rbf', 'poly', 'sigmoid']}
param_grind_without_oversampling = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001], 'kernel': ['rbf', 'poly', 'sigmoid']}

# Use GridSearchCV to find the optimal hyperparameters
grid = GridSearchCV(svr, param_grid, verbose=3)
grid_without_oversampling = GridSearchCV(svr_without_oversampling, param_grind_without_oversampling, verbose=3)

# Fit the model on the training data
grid.fit(X_train, y_train)
grid_without_oversampling.fit(X_train_without_oversampling, y_train_without_oversampling)

# Get the optimal hyperparameters
print(grid.best_params_)
print(grid_without_oversampling.best_params_)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.787 total time=   2.3s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.269 total time=   2.3s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.041 total time=   2.3s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.112 total time=   2.3s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.416 total time=   2.3s
# [CV 1/5] END ......C=0.1, gamma=1, kernel=poly;, score=-0.272 total time=   2.2s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.049 total time=   2.2s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.111 total time=   2.1s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.187 total time=   2.1s
# [CV 5/5] END ......C=0.1, gamma=1, kernel=poly;, score=-0.021 total time=   2.1s
# [CV 1/5] END ...C=0.1, gamma=1, kernel=sigmoid;, score=-0.787 total time=   2.4s
# [CV 2/5] END ...C=0.1, gamma=1, kernel=sigmoid;, score=-0.269 total time=   2.3s
# [CV 3/5] END ...C=0.1, gamma=1, kernel=sigmoid;, score=-0.041 total time=   2.4s
# [CV 4/5] END ...C=0.1, gamma=1, kernel=sigmoid;, score=-0.112 total time=   2.3s
# [CV 5/5] END ...C=0.1, gamma=1, kernel=sigmoid;, score=-0.416 total time=   2.3s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.786 total time=   2.3s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.269 total time=   2.4s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.041 total time=   2.3s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.111 total time=   2.3s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.416 total time=   2.4s
# [CV 1/5] END ....C=0.1, gamma=0.1, kernel=poly;, score=-0.786 total time=   2.3s
# [CV 2/5] END ....C=0.1, gamma=0.1, kernel=poly;, score=-0.269 total time=   2.1s
# [CV 3/5] END ....C=0.1, gamma=0.1, kernel=poly;, score=-0.041 total time=   2.1s
# [CV 4/5] END ....C=0.1, gamma=0.1, kernel=poly;, score=-0.111 total time=   2.1s
# [CV 5/5] END ....C=0.1, gamma=0.1, kernel=poly;, score=-0.416 total time=   2.0s
# [CV 1/5] END .C=0.1, gamma=0.1, kernel=sigmoid;, score=-0.786 total time=   2.3s
# [CV 2/5] END .C=0.1, gamma=0.1, kernel=sigmoid;, score=-0.269 total time=   2.3s
# [CV 3/5] END .C=0.1, gamma=0.1, kernel=sigmoid;, score=-0.041 total time=   2.3s
# [CV 4/5] END .C=0.1, gamma=0.1, kernel=sigmoid;, score=-0.111 total time=   2.3s
# [CV 5/5] END .C=0.1, gamma=0.1, kernel=sigmoid;, score=-0.416 total time=   2.3s
# [CV 1/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.787 total time=   2.3s
# [CV 2/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.269 total time=   2.3s
# [CV 3/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.041 total time=   2.3s
# [CV 4/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.112 total time=   2.3s
# [CV 5/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.416 total time=   2.2s
# [CV 1/5] END ...C=0.1, gamma=0.01, kernel=poly;, score=-0.787 total time=   2.1s
# [CV 2/5] END ...C=0.1, gamma=0.01, kernel=poly;, score=-0.269 total time=   2.1s
# [CV 3/5] END ...C=0.1, gamma=0.01, kernel=poly;, score=-0.041 total time=   2.0s
# [CV 4/5] END ...C=0.1, gamma=0.01, kernel=poly;, score=-0.112 total time=   2.0s
# [CV 5/5] END ...C=0.1, gamma=0.01, kernel=poly;, score=-0.416 total time=   2.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=sigmoid;, score=-0.787 total time=   2.1s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=sigmoid;, score=-0.269 total time=   2.1s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=sigmoid;, score=-0.041 total time=   2.1s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=sigmoid;, score=-0.112 total time=   2.2s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=sigmoid;, score=-0.416 total time=   2.1s
# [CV 1/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.787 total time=   2.3s
# [CV 2/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.269 total time=   2.3s
# [CV 3/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.041 total time=   2.3s
# [CV 4/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.112 total time=   2.3s
# [CV 5/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.416 total time=   2.2s
# [CV 1/5] END ..C=0.1, gamma=0.001, kernel=poly;, score=-0.787 total time=   2.1s
# [CV 2/5] END ..C=0.1, gamma=0.001, kernel=poly;, score=-0.269 total time=   2.1s
# [CV 3/5] END ..C=0.1, gamma=0.001, kernel=poly;, score=-0.041 total time=   2.0s
# [CV 4/5] END ..C=0.1, gamma=0.001, kernel=poly;, score=-0.112 total time=   2.0s
# [CV 5/5] END ..C=0.1, gamma=0.001, kernel=poly;, score=-0.416 total time=   2.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=-0.787 total time=   2.1s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=-0.269 total time=   2.2s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=-0.041 total time=   2.1s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=-0.112 total time=   2.1s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=-0.416 total time=   2.1s
# [CV 1/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.787 total time=   2.3s
# [CV 2/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.269 total time=   2.3s
# [CV 3/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.041 total time=   2.3s
# [CV 4/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.112 total time=   2.3s
# [CV 5/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.416 total time=   2.2s
# [CV 1/5] END .........C=1, gamma=1, kernel=poly;, score=0.218 total time=   2.0s
# [CV 2/5] END .........C=1, gamma=1, kernel=poly;, score=0.384 total time=   2.0s
# [CV 3/5] END .........C=1, gamma=1, kernel=poly;, score=0.391 total time=   1.9s
# [CV 4/5] END .........C=1, gamma=1, kernel=poly;, score=0.536 total time=   2.0s
# [CV 5/5] END .........C=1, gamma=1, kernel=poly;, score=0.376 total time=   2.0s
# [CV 1/5] END .....C=1, gamma=1, kernel=sigmoid;, score=-0.782 total time=   2.4s
# [CV 2/5] END .....C=1, gamma=1, kernel=sigmoid;, score=-0.269 total time=   2.3s
# [CV 3/5] END .....C=1, gamma=1, kernel=sigmoid;, score=-0.040 total time=   2.3s
# [CV 4/5] END .....C=1, gamma=1, kernel=sigmoid;, score=-0.109 total time=   2.3s
# [CV 5/5] END .....C=1, gamma=1, kernel=sigmoid;, score=-0.413 total time=   2.3s
# [CV 1/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.774 total time=   2.3s
# [CV 2/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.267 total time=   2.3s
# [CV 3/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.039 total time=   2.2s
# [CV 4/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.105 total time=   2.3s
# [CV 5/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.413 total time=   2.2s
# [CV 1/5] END ......C=1, gamma=0.1, kernel=poly;, score=-0.776 total time=   2.1s
# [CV 2/5] END ......C=1, gamma=0.1, kernel=poly;, score=-0.266 total time=   2.1s
# [CV 3/5] END ......C=1, gamma=0.1, kernel=poly;, score=-0.039 total time=   2.0s
# [CV 4/5] END ......C=1, gamma=0.1, kernel=poly;, score=-0.105 total time=   2.0s
# [CV 5/5] END ......C=1, gamma=0.1, kernel=poly;, score=-0.413 total time=   2.0s
# [CV 1/5] END ...C=1, gamma=0.1, kernel=sigmoid;, score=-0.770 total time=   2.3s
# [CV 2/5] END ...C=1, gamma=0.1, kernel=sigmoid;, score=-0.266 total time=   2.3s
# [CV 3/5] END ...C=1, gamma=0.1, kernel=sigmoid;, score=-0.038 total time=   2.2s
# [CV 4/5] END ...C=1, gamma=0.1, kernel=sigmoid;, score=-0.103 total time=   2.2s
# [CV 5/5] END ...C=1, gamma=0.1, kernel=sigmoid;, score=-0.411 total time=   2.2s
# [CV 1/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.784 total time=   2.4s
# [CV 2/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.269 total time=   2.3s
# [CV 3/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.040 total time=   2.3s
# [CV 4/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.110 total time=   2.3s
# [CV 5/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.415 total time=   2.2s
# [CV 1/5] END .....C=1, gamma=0.01, kernel=poly;, score=-0.787 total time=   2.1s
# [CV 2/5] END .....C=1, gamma=0.01, kernel=poly;, score=-0.269 total time=   2.1s
# [CV 3/5] END .....C=1, gamma=0.01, kernel=poly;, score=-0.041 total time=   2.0s
# [CV 4/5] END .....C=1, gamma=0.01, kernel=poly;, score=-0.112 total time=   2.0s
# [CV 5/5] END .....C=1, gamma=0.01, kernel=poly;, score=-0.416 total time=   2.0s
# [CV 1/5] END ..C=1, gamma=0.01, kernel=sigmoid;, score=-0.785 total time=   2.2s
# [CV 2/5] END ..C=1, gamma=0.01, kernel=sigmoid;, score=-0.269 total time=   2.3s
# [CV 3/5] END ..C=1, gamma=0.01, kernel=sigmoid;, score=-0.041 total time=   2.1s
# [CV 4/5] END ..C=1, gamma=0.01, kernel=sigmoid;, score=-0.111 total time=   2.2s
# [CV 5/5] END ..C=1, gamma=0.01, kernel=sigmoid;, score=-0.415 total time=   2.2s
# [CV 1/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.787 total time=   2.3s
# [CV 2/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.269 total time=   2.3s
# [CV 3/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.041 total time=   2.3s
# [CV 4/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.112 total time=   2.3s
# [CV 5/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.416 total time=   2.3s
# [CV 1/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.787 total time=   2.1s
# [CV 2/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.269 total time=   2.0s
# [CV 3/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.041 total time=   2.0s
# [CV 4/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.112 total time=   2.0s
# [CV 5/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.416 total time=   2.0s
# [CV 1/5] END .C=1, gamma=0.001, kernel=sigmoid;, score=-0.787 total time=   2.2s
# [CV 2/5] END .C=1, gamma=0.001, kernel=sigmoid;, score=-0.269 total time=   2.2s
# [CV 3/5] END .C=1, gamma=0.001, kernel=sigmoid;, score=-0.041 total time=   2.1s
# [CV 4/5] END .C=1, gamma=0.001, kernel=sigmoid;, score=-0.112 total time=   2.1s
# [CV 5/5] END .C=1, gamma=0.001, kernel=sigmoid;, score=-0.416 total time=   2.1s
# [CV 1/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.786 total time=   2.3s
# [CV 2/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.269 total time=   2.3s
# [CV 3/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.040 total time=   2.3s
# [CV 4/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.107 total time=   2.4s
# [CV 5/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.413 total time=   2.3s
# [CV 1/5] END ........C=10, gamma=1, kernel=poly;, score=0.456 total time=   1.3s
# [CV 2/5] END ........C=10, gamma=1, kernel=poly;, score=0.632 total time=   1.5s
# [CV 3/5] END ........C=10, gamma=1, kernel=poly;, score=0.669 total time=   1.6s
# [CV 4/5] END ........C=10, gamma=1, kernel=poly;, score=0.882 total time=   1.8s
# [CV 5/5] END ........C=10, gamma=1, kernel=poly;, score=0.786 total time=   1.8s
# [CV 1/5] END ....C=10, gamma=1, kernel=sigmoid;, score=-0.739 total time=   2.3s
# [CV 2/5] END ....C=10, gamma=1, kernel=sigmoid;, score=-0.261 total time=   2.3s
# [CV 3/5] END ....C=10, gamma=1, kernel=sigmoid;, score=-0.034 total time=   2.4s
# [CV 4/5] END ....C=10, gamma=1, kernel=sigmoid;, score=-0.086 total time=   2.3s
# [CV 5/5] END ....C=10, gamma=1, kernel=sigmoid;, score=-0.397 total time=   2.3s
# [CV 1/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.676 total time=   2.3s
# [CV 2/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.238 total time=   2.3s
# [CV 3/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.022 total time=   2.3s
# [CV 4/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.050 total time=   2.2s
# [CV 5/5] END ......C=10, gamma=0.1, kernel=rbf;, score=-0.353 total time=   2.2s
# [CV 1/5] END .....C=10, gamma=0.1, kernel=poly;, score=-0.681 total time=   2.1s
# [CV 2/5] END .....C=10, gamma=0.1, kernel=poly;, score=-0.241 total time=   2.1s
# [CV 3/5] END .....C=10, gamma=0.1, kernel=poly;, score=-0.025 total time=   2.0s
# [CV 4/5] END .....C=10, gamma=0.1, kernel=poly;, score=-0.055 total time=   2.2s
# [CV 5/5] END .....C=10, gamma=0.1, kernel=poly;, score=-0.359 total time=   2.0s
# [CV 1/5] END ..C=10, gamma=0.1, kernel=sigmoid;, score=-0.653 total time=   2.3s
# [CV 2/5] END ..C=10, gamma=0.1, kernel=sigmoid;, score=-0.231 total time=   2.3s
# [CV 3/5] END ..C=10, gamma=0.1, kernel=sigmoid;, score=-0.011 total time=   2.2s
# [CV 4/5] END ..C=10, gamma=0.1, kernel=sigmoid;, score=-0.038 total time=   2.2s
# [CV 5/5] END ..C=10, gamma=0.1, kernel=sigmoid;, score=-0.342 total time=   2.2s
# [CV 1/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.752 total time=   2.4s
# [CV 2/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.262 total time=   2.4s
# [CV 3/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.036 total time=   2.3s
# [CV 4/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.093 total time=   2.3s
# [CV 5/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.402 total time=   2.2s
# [CV 1/5] END ....C=10, gamma=0.01, kernel=poly;, score=-0.787 total time=   2.1s
# [CV 2/5] END ....C=10, gamma=0.01, kernel=poly;, score=-0.269 total time=   2.0s
# [CV 3/5] END ....C=10, gamma=0.01, kernel=poly;, score=-0.041 total time=   2.0s
# [CV 4/5] END ....C=10, gamma=0.01, kernel=poly;, score=-0.112 total time=   2.0s
# [CV 5/5] END ....C=10, gamma=0.01, kernel=poly;, score=-0.416 total time=   2.1s
# [CV 1/5] END .C=10, gamma=0.01, kernel=sigmoid;, score=-0.767 total time=   2.1s
# [CV 2/5] END .C=10, gamma=0.01, kernel=sigmoid;, score=-0.265 total time=   2.1s
# [CV 3/5] END .C=10, gamma=0.01, kernel=sigmoid;, score=-0.038 total time=   2.1s
# [CV 4/5] END .C=10, gamma=0.01, kernel=sigmoid;, score=-0.102 total time=   2.1s
# [CV 5/5] END .C=10, gamma=0.01, kernel=sigmoid;, score=-0.410 total time=   2.1s
# [CV 1/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.783 total time=   2.3s
# [CV 2/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.269 total time=   2.3s
# [CV 3/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.040 total time=   2.2s
# [CV 4/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.110 total time=   2.2s
# [CV 5/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.415 total time=   2.2s
# [CV 1/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.787 total time=   2.1s
# [CV 2/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.269 total time=   2.0s
# [CV 3/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.041 total time=   2.0s
# [CV 4/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.112 total time=   2.0s
# [CV 5/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.416 total time=   2.0s
# [CV 1/5] END C=10, gamma=0.001, kernel=sigmoid;, score=-0.785 total time=   2.1s
# [CV 2/5] END C=10, gamma=0.001, kernel=sigmoid;, score=-0.269 total time=   2.1s
# [CV 3/5] END C=10, gamma=0.001, kernel=sigmoid;, score=-0.041 total time=   2.1s
# [CV 4/5] END C=10, gamma=0.001, kernel=sigmoid;, score=-0.111 total time=   2.1s
# [CV 5/5] END C=10, gamma=0.001, kernel=sigmoid;, score=-0.415 total time=   2.1s
# [CV 1/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.754 total time=   2.4s
# [CV 2/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.260 total time=   2.4s
# [CV 3/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.034 total time=   2.4s
# [CV 4/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.064 total time=   2.3s
# [CV 5/5] END .......C=100, gamma=1, kernel=rbf;, score=-0.382 total time=   2.3s
# [CV 1/5] END .......C=100, gamma=1, kernel=poly;, score=0.653 total time=   1.7s
# [CV 2/5] END .......C=100, gamma=1, kernel=poly;, score=0.874 total time=   2.7s
# [CV 3/5] END .......C=100, gamma=1, kernel=poly;, score=0.937 total time=   7.0s
# [CV 4/5] END .......C=100, gamma=1, kernel=poly;, score=1.000 total time=   8.3s
# [CV 5/5] END .......C=100, gamma=1, kernel=poly;, score=1.000 total time=   8.4s
# [CV 1/5] END ...C=100, gamma=1, kernel=sigmoid;, score=-0.497 total time=   2.4s
# [CV 2/5] END ...C=100, gamma=1, kernel=sigmoid;, score=-0.181 total time=   2.4s
# [CV 3/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.035 total time=   2.3s
# [CV 4/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.026 total time=   2.3s
# [CV 5/5] END ...C=100, gamma=1, kernel=sigmoid;, score=-0.246 total time=   2.3s
# [CV 1/5] END .....C=100, gamma=0.1, kernel=rbf;, score=-0.242 total time=   2.3s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.062 total time=   2.4s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.141 total time=   2.4s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.211 total time=   2.3s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.016 total time=   2.3s
# [CV 1/5] END ....C=100, gamma=0.1, kernel=poly;, score=-0.272 total time=   2.1s
# [CV 2/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.049 total time=   2.1s
# [CV 3/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.111 total time=   2.1s
# [CV 4/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.187 total time=   2.1s
# [CV 5/5] END ....C=100, gamma=0.1, kernel=poly;, score=-0.021 total time=   2.1s
# [CV 1/5] END .C=100, gamma=0.1, kernel=sigmoid;, score=-0.126 total time=   2.3s
# [CV 2/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.101 total time=   2.3s
# [CV 3/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.180 total time=   2.2s
# [CV 4/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.257 total time=   2.3s
# [CV 5/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.080 total time=   2.2s
# [CV 1/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.551 total time=   2.3s
# [CV 2/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.172 total time=   2.3s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.019 total time=   2.3s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.023 total time=   2.2s
# [CV 5/5] END ....C=100, gamma=0.01, kernel=rbf;, score=-0.251 total time=   2.2s
# [CV 1/5] END ...C=100, gamma=0.01, kernel=poly;, score=-0.786 total time=   2.0s
# [CV 2/5] END ...C=100, gamma=0.01, kernel=poly;, score=-0.269 total time=   2.1s
# [CV 3/5] END ...C=100, gamma=0.01, kernel=poly;, score=-0.041 total time=   2.0s
# [CV 4/5] END ...C=100, gamma=0.01, kernel=poly;, score=-0.111 total time=   2.0s
# [CV 5/5] END ...C=100, gamma=0.01, kernel=poly;, score=-0.416 total time=   2.0s
# [CV 1/5] END C=100, gamma=0.01, kernel=sigmoid;, score=-0.630 total time=   2.1s
# [CV 2/5] END C=100, gamma=0.01, kernel=sigmoid;, score=-0.217 total time=   2.1s
# [CV 3/5] END C=100, gamma=0.01, kernel=sigmoid;, score=-0.005 total time=   2.1s
# [CV 4/5] END C=100, gamma=0.01, kernel=sigmoid;, score=-0.028 total time=   2.1s
# [CV 5/5] END C=100, gamma=0.01, kernel=sigmoid;, score=-0.321 total time=   2.1s
# [CV 1/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.748 total time=   2.3s
# [CV 2/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.262 total time=   2.3s
# [CV 3/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.035 total time=   2.2s
# [CV 4/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.091 total time=   2.2s
# [CV 5/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.401 total time=   2.2s
# [CV 1/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.787 total time=   2.1s
# [CV 2/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.269 total time=   2.1s
# [CV 3/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.041 total time=   2.0s
# [CV 4/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.112 total time=   2.0s
# [CV 5/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.416 total time=   2.0s
# [CV 1/5] END C=100, gamma=0.001, kernel=sigmoid;, score=-0.767 total time=   2.1s
# [CV 2/5] END C=100, gamma=0.001, kernel=sigmoid;, score=-0.265 total time=   2.1s
# [CV 3/5] END C=100, gamma=0.001, kernel=sigmoid;, score=-0.038 total time=   2.1s
# [CV 4/5] END C=100, gamma=0.001, kernel=sigmoid;, score=-0.102 total time=   2.1s
# [CV 5/5] END C=100, gamma=0.001, kernel=sigmoid;, score=-0.410 total time=   2.1s
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.004 total time=   0.4s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.003 total time=   0.3s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.005 total time=   0.4s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.002 total time=   0.3s
# [CV 1/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.064 total time=   0.3s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.073 total time=   0.3s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.064 total time=   0.3s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.068 total time=   0.3s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.083 total time=   0.4s
# [CV 1/5] END ...C=0.1, gamma=1, kernel=sigmoid;, score=-0.004 total time=   0.4s
# [CV 2/5] END ...C=0.1, gamma=1, kernel=sigmoid;, score=-0.004 total time=   0.4s
# [CV 3/5] END ...C=0.1, gamma=1, kernel=sigmoid;, score=-0.003 total time=   0.4s
# [CV 4/5] END ...C=0.1, gamma=1, kernel=sigmoid;, score=-0.005 total time=   0.4s
# [CV 5/5] END ...C=0.1, gamma=1, kernel=sigmoid;, score=-0.002 total time=   0.4s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.003 total time=   0.3s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.005 total time=   0.3s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.002 total time=   0.3s
# [CV 1/5] END ....C=0.1, gamma=0.1, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 2/5] END ....C=0.1, gamma=0.1, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 3/5] END ....C=0.1, gamma=0.1, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 4/5] END ....C=0.1, gamma=0.1, kernel=poly;, score=-0.005 total time=   0.3s
# [CV 5/5] END ....C=0.1, gamma=0.1, kernel=poly;, score=-0.002 total time=   0.3s
# [CV 1/5] END .C=0.1, gamma=0.1, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 2/5] END .C=0.1, gamma=0.1, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 3/5] END .C=0.1, gamma=0.1, kernel=sigmoid;, score=-0.003 total time=   0.3s
# [CV 4/5] END .C=0.1, gamma=0.1, kernel=sigmoid;, score=-0.005 total time=   0.3s
# [CV 5/5] END .C=0.1, gamma=0.1, kernel=sigmoid;, score=-0.002 total time=   0.4s
# [CV 1/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.004 total time=   0.4s
# [CV 2/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.004 total time=   0.4s
# [CV 3/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.003 total time=   0.4s
# [CV 4/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.005 total time=   0.4s
# [CV 5/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.002 total time=   0.3s
# [CV 1/5] END ...C=0.1, gamma=0.01, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 2/5] END ...C=0.1, gamma=0.01, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 3/5] END ...C=0.1, gamma=0.01, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 4/5] END ...C=0.1, gamma=0.01, kernel=poly;, score=-0.005 total time=   0.3s
# [CV 5/5] END ...C=0.1, gamma=0.01, kernel=poly;, score=-0.002 total time=   0.3s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=sigmoid;, score=-0.003 total time=   0.3s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=sigmoid;, score=-0.005 total time=   0.3s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=sigmoid;, score=-0.002 total time=   0.3s
# [CV 1/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 2/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 3/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.003 total time=   0.3s
# [CV 4/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.005 total time=   0.3s
# [CV 5/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.002 total time=   0.4s
# [CV 1/5] END ..C=0.1, gamma=0.001, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 2/5] END ..C=0.1, gamma=0.001, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 3/5] END ..C=0.1, gamma=0.001, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 4/5] END ..C=0.1, gamma=0.001, kernel=poly;, score=-0.005 total time=   0.3s
# [CV 5/5] END ..C=0.1, gamma=0.001, kernel=poly;, score=-0.002 total time=   0.3s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=-0.003 total time=   0.3s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=-0.005 total time=   0.3s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=-0.002 total time=   0.3s
# [CV 1/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 2/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 3/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.003 total time=   0.3s
# [CV 4/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.005 total time=   0.3s
# [CV 5/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.002 total time=   0.3s
# [CV 1/5] END .........C=1, gamma=1, kernel=poly;, score=0.256 total time=   0.3s
# [CV 2/5] END .........C=1, gamma=1, kernel=poly;, score=0.272 total time=   0.3s
# [CV 3/5] END .........C=1, gamma=1, kernel=poly;, score=0.249 total time=   0.3s
# [CV 4/5] END .........C=1, gamma=1, kernel=poly;, score=0.277 total time=   0.3s
# [CV 5/5] END .........C=1, gamma=1, kernel=poly;, score=0.342 total time=   0.3s
# [CV 1/5] END .....C=1, gamma=1, kernel=sigmoid;, score=-0.004 total time=   0.4s
# [CV 2/5] END .....C=1, gamma=1, kernel=sigmoid;, score=-0.004 total time=   0.4s
# [CV 3/5] END .....C=1, gamma=1, kernel=sigmoid;, score=-0.003 total time=   0.4s
# [CV 4/5] END .....C=1, gamma=1, kernel=sigmoid;, score=-0.005 total time=   0.4s
# [CV 5/5] END .....C=1, gamma=1, kernel=sigmoid;, score=-0.002 total time=   0.4s
# [CV 1/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.003 total time=   0.4s
# [CV 2/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.003 total time=   0.4s
# [CV 3/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.002 total time=   0.3s
# [CV 4/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 5/5] END .......C=1, gamma=0.1, kernel=rbf;, score=-0.001 total time=   0.3s
# [CV 1/5] END ......C=1, gamma=0.1, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 2/5] END ......C=1, gamma=0.1, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 3/5] END ......C=1, gamma=0.1, kernel=poly;, score=-0.002 total time=   0.3s
# [CV 4/5] END ......C=1, gamma=0.1, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 5/5] END ......C=1, gamma=0.1, kernel=poly;, score=-0.001 total time=   0.3s
# [CV 1/5] END ...C=1, gamma=0.1, kernel=sigmoid;, score=-0.003 total time=   0.4s
# [CV 2/5] END ...C=1, gamma=0.1, kernel=sigmoid;, score=-0.003 total time=   0.4s
# [CV 3/5] END ...C=1, gamma=0.1, kernel=sigmoid;, score=-0.002 total time=   0.3s
# [CV 4/5] END ...C=1, gamma=0.1, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 5/5] END ...C=1, gamma=0.1, kernel=sigmoid;, score=-0.001 total time=   0.4s
# [CV 1/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.004 total time=   0.4s
# [CV 2/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.004 total time=   0.4s
# [CV 3/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.003 total time=   0.3s
# [CV 4/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.005 total time=   0.4s
# [CV 5/5] END ......C=1, gamma=0.01, kernel=rbf;, score=-0.002 total time=   0.3s
# [CV 1/5] END .....C=1, gamma=0.01, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 2/5] END .....C=1, gamma=0.01, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 3/5] END .....C=1, gamma=0.01, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 4/5] END .....C=1, gamma=0.01, kernel=poly;, score=-0.005 total time=   0.3s
# [CV 5/5] END .....C=1, gamma=0.01, kernel=poly;, score=-0.002 total time=   0.3s
# [CV 1/5] END ..C=1, gamma=0.01, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 2/5] END ..C=1, gamma=0.01, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 3/5] END ..C=1, gamma=0.01, kernel=sigmoid;, score=-0.003 total time=   0.3s
# [CV 4/5] END ..C=1, gamma=0.01, kernel=sigmoid;, score=-0.005 total time=   0.3s
# [CV 5/5] END ..C=1, gamma=0.01, kernel=sigmoid;, score=-0.002 total time=   0.3s
# [CV 1/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 2/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 3/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.003 total time=   0.3s
# [CV 4/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.005 total time=   0.3s
# [CV 5/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.002 total time=   0.3s
# [CV 1/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 2/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 3/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 4/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.005 total time=   0.3s
# [CV 5/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.002 total time=   0.3s
# [CV 1/5] END .C=1, gamma=0.001, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 2/5] END .C=1, gamma=0.001, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 3/5] END .C=1, gamma=0.001, kernel=sigmoid;, score=-0.003 total time=   0.3s
# [CV 4/5] END .C=1, gamma=0.001, kernel=sigmoid;, score=-0.005 total time=   0.3s
# [CV 5/5] END .C=1, gamma=0.001, kernel=sigmoid;, score=-0.002 total time=   0.3s
# [CV 1/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.004 total time=   0.4s
# [CV 2/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.003 total time=   0.4s
# [CV 3/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.002 total time=   0.4s
# [CV 4/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.005 total time=   0.3s
# [CV 5/5] END ........C=10, gamma=1, kernel=rbf;, score=-0.002 total time=   0.3s
# [CV 1/5] END ........C=10, gamma=1, kernel=poly;, score=0.493 total time=   0.3s
# [CV 2/5] END ........C=10, gamma=1, kernel=poly;, score=0.479 total time=   0.3s
# [CV 3/5] END ........C=10, gamma=1, kernel=poly;, score=0.464 total time=   0.3s
# [CV 4/5] END ........C=10, gamma=1, kernel=poly;, score=0.544 total time=   0.3s
# [CV 5/5] END ........C=10, gamma=1, kernel=poly;, score=0.581 total time=   0.3s
# [CV 1/5] END ....C=10, gamma=1, kernel=sigmoid;, score=-0.003 total time=   0.4s
# [CV 2/5] END ....C=10, gamma=1, kernel=sigmoid;, score=-0.003 total time=   0.4s
# [CV 3/5] END ....C=10, gamma=1, kernel=sigmoid;, score=-0.001 total time=   0.4s
# [CV 4/5] END ....C=10, gamma=1, kernel=sigmoid;, score=-0.004 total time=   0.4s
# [CV 5/5] END ....C=10, gamma=1, kernel=sigmoid;, score=-0.001 total time=   0.4s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.002 total time=   0.3s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.005 total time=   0.3s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.004 total time=   0.3s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.003 total time=   0.3s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.007 total time=   0.3s
# [CV 1/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.003 total time=   0.3s
# [CV 2/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.006 total time=   0.3s
# [CV 3/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.005 total time=   0.3s
# [CV 4/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.003 total time=   0.3s
# [CV 5/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.008 total time=   0.3s
# [CV 1/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.003 total time=   0.3s
# [CV 2/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.005 total time=   0.4s
# [CV 3/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.005 total time=   0.4s
# [CV 4/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.003 total time=   0.4s
# [CV 5/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.007 total time=   0.3s
# [CV 1/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.003 total time=   0.3s
# [CV 2/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.002 total time=   0.3s
# [CV 3/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.001 total time=   0.4s
# [CV 4/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.003 total time=   0.3s
# [CV 5/5] END .....C=10, gamma=0.01, kernel=rbf;, score=-0.000 total time=   0.3s
# [CV 1/5] END ....C=10, gamma=0.01, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 2/5] END ....C=10, gamma=0.01, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 3/5] END ....C=10, gamma=0.01, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 4/5] END ....C=10, gamma=0.01, kernel=poly;, score=-0.005 total time=   0.3s
# [CV 5/5] END ....C=10, gamma=0.01, kernel=poly;, score=-0.002 total time=   0.3s
# [CV 1/5] END .C=10, gamma=0.01, kernel=sigmoid;, score=-0.003 total time=   0.3s
# [CV 2/5] END .C=10, gamma=0.01, kernel=sigmoid;, score=-0.003 total time=   0.3s
# [CV 3/5] END .C=10, gamma=0.01, kernel=sigmoid;, score=-0.002 total time=   0.3s
# [CV 4/5] END .C=10, gamma=0.01, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 5/5] END .C=10, gamma=0.01, kernel=sigmoid;, score=-0.001 total time=   0.3s
# [CV 1/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 2/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.004 total time=   0.3s
# [CV 3/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.003 total time=   0.3s
# [CV 4/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.005 total time=   0.3s
# [CV 5/5] END ....C=10, gamma=0.001, kernel=rbf;, score=-0.002 total time=   0.3s
# [CV 1/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 2/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 3/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 4/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.005 total time=   0.3s
# [CV 5/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.002 total time=   0.3s
# [CV 1/5] END C=10, gamma=0.001, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 2/5] END C=10, gamma=0.001, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 3/5] END C=10, gamma=0.001, kernel=sigmoid;, score=-0.003 total time=   0.3s
# [CV 4/5] END C=10, gamma=0.001, kernel=sigmoid;, score=-0.005 total time=   0.3s
# [CV 5/5] END C=10, gamma=0.001, kernel=sigmoid;, score=-0.002 total time=   0.3s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.000 total time=   0.3s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.003 total time=   0.4s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.002 total time=   0.4s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.001 total time=   0.3s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.004 total time=   0.3s
# [CV 1/5] END .......C=100, gamma=1, kernel=poly;, score=0.715 total time=   1.5s
# [CV 2/5] END .......C=100, gamma=1, kernel=poly;, score=0.713 total time=   1.5s
# [CV 3/5] END .......C=100, gamma=1, kernel=poly;, score=0.676 total time=   2.5s
# [CV 4/5] END .......C=100, gamma=1, kernel=poly;, score=0.775 total time=   1.6s
# [CV 5/5] END .......C=100, gamma=1, kernel=poly;, score=0.801 total time=   1.4s
# [CV 1/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.005 total time=   0.4s
# [CV 2/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.007 total time=   0.4s
# [CV 3/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.011 total time=   0.4s
# [CV 4/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.005 total time=   0.4s
# [CV 5/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.007 total time=   0.4s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.062 total time=   0.4s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.069 total time=   0.4s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.063 total time=   0.4s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.066 total time=   0.4s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.079 total time=   0.4s
# [CV 1/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.064 total time=   0.3s
# [CV 2/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.073 total time=   0.3s
# [CV 3/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.064 total time=   0.3s
# [CV 4/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.068 total time=   0.3s
# [CV 5/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.083 total time=   0.3s
# [CV 1/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.066 total time=   0.4s
# [CV 2/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.071 total time=   0.4s
# [CV 3/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.064 total time=   0.4s
# [CV 4/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.067 total time=   0.4s
# [CV 5/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.080 total time=   0.4s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.013 total time=   0.3s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.016 total time=   0.3s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.014 total time=   0.4s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.013 total time=   0.4s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.019 total time=   0.4s
# [CV 1/5] END ...C=100, gamma=0.01, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 2/5] END ...C=100, gamma=0.01, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 3/5] END ...C=100, gamma=0.01, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 4/5] END ...C=100, gamma=0.01, kernel=poly;, score=-0.005 total time=   0.3s
# [CV 5/5] END ...C=100, gamma=0.01, kernel=poly;, score=-0.002 total time=   0.3s
# [CV 1/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.005 total time=   0.3s
# [CV 2/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.008 total time=   0.3s
# [CV 3/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.007 total time=   0.3s
# [CV 4/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.005 total time=   0.3s
# [CV 5/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.010 total time=   0.3s
# [CV 1/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.002 total time=   0.4s
# [CV 2/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.001 total time=   0.4s
# [CV 3/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.001 total time=   0.4s
# [CV 4/5] END ...C=100, gamma=0.001, kernel=rbf;, score=-0.003 total time=   0.4s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.000 total time=   0.3s
# [CV 1/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 2/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.004 total time=   0.3s
# [CV 3/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.003 total time=   0.3s
# [CV 4/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.005 total time=   0.3s
# [CV 5/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.002 total time=   0.3s
# [CV 1/5] END C=100, gamma=0.001, kernel=sigmoid;, score=-0.003 total time=   0.3s
# [CV 2/5] END C=100, gamma=0.001, kernel=sigmoid;, score=-0.003 total time=   0.3s
# [CV 3/5] END C=100, gamma=0.001, kernel=sigmoid;, score=-0.002 total time=   0.3s
# [CV 4/5] END C=100, gamma=0.001, kernel=sigmoid;, score=-0.004 total time=   0.3s
# [CV 5/5] END C=100, gamma=0.001, kernel=sigmoid;, score=-0.001 total time=   0.3s
# {'C': 100, 'gamma': 1, 'kernel': 'poly'}
# {'C': 100, 'gamma': 1, 'kernel': 'poly'}

# %%
# Make predictions using the test set
y_pred = grid.predict(X_test)
y_pred_without_oversampling = grid_without_oversampling.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mse_without_oversampling = mean_squared_error(y_test, y_pred_without_oversampling)
r2 = r2_score(y_test, y_pred)
r2_without_oversampling = r2_score(y_test, y_pred_without_oversampling)

print("With oversampling")
print('Mean Squared Error:', mse)
print('R^2 Score:', r2)
print('_____________')
print("Without oversampling")
print('Mean Squared Error:', mse_without_oversampling)
print('R^2 Score:', r2_without_oversampling)
# Out:
# With oversampling
# Mean Squared Error: 1230377926.388596
# R^2 Score: 0.6896649983728148
# _____________
# Without oversampling
# Mean Squared Error: 1229159794.131475
# R^2 Score: 0.6899722446813579
